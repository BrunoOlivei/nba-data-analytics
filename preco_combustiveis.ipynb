# %%
import pandas as pd
import numpy as np

# %%
ano = 2021
mes = '08'

# %%
url = f'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsan/{ano}/{ano}-{mes}-gasolina-etanol.csv'

# %%
df_original = pd.read_csv(url, sep = ';', decimal = ',')

# %%
df_original
# Out:
#       Região - Sigla Estado - Sigla  Município  \
# 0                 NE             CE  MARACANAU
# 1                 NE             CE  MARACANAU
# 2                 NE             CE  MARACANAU
# 3                 NE             CE  MARACANAU
# 4                 NE             CE  MARACANAU
# ...              ...            ...        ...
# 47844             SE             ES    ARACRUZ
# 47845             SE             ES    ARACRUZ
# 47846             SE             ES    ARACRUZ
# 47847             SE             MG      ARAXA
# 47848             SE             MG      ARAXA
#
#                                             Revenda      CNPJ da Revenda  \
# 0      BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 1      BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 2      BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.   05.397.086/0001-51
# 3                         LUIZA GLAURIA R T MENEZES   03.602.329/0001-10
# ...

# %%
df_original.columns
# Out:
# Index(['Região - Sigla', 'Estado - Sigla', 'Município', 'Revenda',
#        'CNPJ da Revenda', 'Nome da Rua', 'Número Rua', 'Complemento', 'Bairro',
#        'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda', 'Valor de Compra',
#        'Unidade de Medida', 'Bandeira'],
#       dtype='object')

# %%
df_original['Data da Coleta'] = pd.to_datetime(df_original['Data da Coleta'], dayfirst = True)

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47849 entries, 0 to 47848
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Região - Sigla     47849 non-null  object
#  1   Estado - Sigla     47849 non-null  object
#  2   Município          47849 non-null  object
#  3   Revenda            47849 non-null  object
#  4   CNPJ da Revenda    47849 non-null  object
#  5   Nome da Rua        47849 non-null  object
#  6   Número Rua         47815 non-null  object
#  7   Complemento        9659 non-null   object
#  8   Bairro             47714 non-null  object
#  9   Cep                47849 non-null  object
#  10  Produto            47849 non-null  object
#  11  Data da Coleta     47849 non-null  datetime64[ns]
#  12  Valor de Venda     47849 non-null  float64
#  13  Valor de Compra    0 non-null      float64
#  14  Unidade de Medida  47849 non-null  object
# ...
