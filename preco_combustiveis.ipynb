# %%
import pandas as pd
import numpy as np

# %%
ano = 2021
mes = '07'

# %%
url = f'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsan/{ano}/{ano}-{mes}-gasolina-etanol.csv'

# %%
df_original = pd.read_csv(url, sep = ';', decimal = ',')

# %%
df_original
# Out:
#       Região - Sigla Estado - Sigla     Município  \
# 0                 NE             BA        ILHEUS
# 1                 NE             BA        ILHEUS
# 2                 NE             BA        ILHEUS
# 3                 NE             BA        ILHEUS
# 4                 NE             BA        ILHEUS
# ...              ...            ...           ...
# 53980              S             RS  PORTO ALEGRE
# 53981              S             RS  PORTO ALEGRE
# 53982             SE             ES       ARACRUZ
# 53983             SE             ES       ARACRUZ
# 53984             SE             ES       ARACRUZ
#
#                                           Revenda      CNPJ da Revenda  \
# 0                 IVAN COELHO PORTO & IRMAOS LTDA   13.322.102/0001-75
# 1                 IVAN COELHO PORTO & IRMAOS LTDA   13.322.102/0001-75
# 2                 IVAN COELHO PORTO & IRMAOS LTDA   13.322.102/0001-75
# 3             POSTO DE SERVICOS DOM EDUARDO LTDA.   13.631.353/0001-31
# 4             POSTO DE SERVICOS DOM EDUARDO LTDA.   13.631.353/0001-31
# ...                                           ...                  ...
# 53980  FULL POWER COMERCIO DE COMBUSTIVEIS EIRELI   37.442.441/0001-53
# 53981  FULL POWER COMERCIO DE COMBUSTIVEIS EIRELI   37.442.441/0001-53
# 53982            POSTO DE COMBUSTIVEL SHOW EIRELI   23.797.660/0001-40
# 53983            POSTO DE COMBUSTIVEL SHOW EIRELI   23.797.660/0001-40
# 53984            POSTO DE COMBUSTIVEL SHOW EIRELI   23.797.660/0001-40
#
#                            Nome da Rua Número Rua    Complemento  \
# 0            RUA A ROD ILHEUS OLIVENCA         SN           KM 0
# 1            RUA A ROD ILHEUS OLIVENCA         SN           KM 0
# 2            RUA A ROD ILHEUS OLIVENCA         SN           KM 0
# 3                      AVENIDA ITABUNA       1814  MODULOS A E B
# 4                      AVENIDA ITABUNA       1814  MODULOS A E B
# ...                                ...        ...            ...
# 53980              AVENIDA TERESOPOLIS       3368            NaN
# 53981              AVENIDA TERESOPOLIS       3368            NaN
# 53982  AVENIDA CORONEL VENANCIO FLORES         28            NaN
# 53983  AVENIDA CORONEL VENANCIO FLORES         28            NaN
# 53984  AVENIDA CORONEL VENANCIO FLORES         28            NaN
#
#               Bairro        Cep             Produto Data da Coleta  \
# 0      SAO FRANCISCO  45650-780            GASOLINA     01/08/2021
# 1      SAO FRANCISCO  45650-780              ETANOL     01/08/2021
# 2      SAO FRANCISCO  45650-780  GASOLINA ADITIVADA     01/08/2021
# 3            BASILIO  45658-565            GASOLINA     01/08/2021
# 4            BASILIO  45658-565              ETANOL     01/08/2021
# ...              ...        ...                 ...            ...
# 53980    TERESOPOLIS  90870-000            GASOLINA     31/08/2021
# 53981    TERESOPOLIS  90870-000  GASOLINA ADITIVADA     31/08/2021
# 53982         CENTRO  29190-010            GASOLINA     31/08/2021
# 53983         CENTRO  29190-010              ETANOL     31/08/2021
# 53984         CENTRO  29190-010  GASOLINA ADITIVADA     31/08/2021
#
#        Valor de Venda  Valor de Compra Unidade de Medida Bandeira
# 0               6.140              NaN        R$ / litro   BRANCA
# 1               5.150              NaN        R$ / litro   BRANCA
# 2               6.140              NaN        R$ / litro   BRANCA
# 3               6.130              NaN        R$ / litro   BRANCA
# 4               5.130              NaN        R$ / litro   BRANCA
# ...               ...              ...               ...      ...
# 53980           6.397              NaN        R$ / litro   RAIZEN
# 53981           6.597              NaN        R$ / litro   RAIZEN
# 53982           5.970              NaN        R$ / litro   BRANCA
# 53983           4.990              NaN        R$ / litro   BRANCA
# 53984           5.970              NaN        R$ / litro   BRANCA
#
# [53985 rows x 16 columns]

# %%
df_original.columns
# Out:
# Index(['Região - Sigla', 'Estado - Sigla', 'Município', 'Revenda',
#        'CNPJ da Revenda', 'Nome da Rua', 'Número Rua', 'Complemento', 'Bairro',
#        'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda', 'Valor de Compra',
#        'Unidade de Medida', 'Bandeira'],
#       dtype='object')
